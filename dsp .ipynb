# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-b50e70f495b6> in <module>
#      19 sa_2wave=sa_2.make_wave(duration=10.5,start=0,framerate=42000)
#      20
# ---> 21 c=sa_wave+ra_wave+ga_wave+ma_wave+pa_wave+dha_wave+ne_wave+sa_2_wave
#      22 #c.plot()
#      23 from IPython.display import Audio
#
# ~\Anaconda3\lib\site-packages\thinkdsp.py in __add__(self, other)
#     672             return self
#     673
# --> 674         assert self.framerate == other.framerate
#     675
#     676         # make an array of times that covers both waves
#
# AssertionError:

# %%
import numpy as n
import numpy.fft as FFT
import matplotlib.pyplot as plt

# %%
day=[n.sin(14*n.pl*t)for t in n.linscape(0,1,50)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-617d5cd53bd4> in <module>
# ----> 1 day=[n.sin(10*n.pl*t)for t in n.linscape(0,1,50)]
#
# AttributeError: module 'numpy' has no attribute 'linscape'

# %%
mounth =[n.sin(4*n.pl*t)for t in n.linscape(0,1,50)]

# %%
year =[n.sin(2*n.pl*t)for t in n.linscape(0,1,50)]

# %%
mixsin {i*j+k for i,j,k in zip(day,mounth,year)}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4b69c2291805> in <module>
# ----> 1 fft_wave = FFT.fft(mixim)
#
# NameError: name 'mixim' is not defined

# %%
import numpy as n
import numpy.fft as FFT
import matplotlib.pyplot as plt
A=[n.sin(10*n.pi*t)for t in n.linspace(0,1,50)]
B =[n.sin(4*n.pi*t)for t in n.linspace (0,1,50)]
C =[n.sin(2*n.pi*t)for t in n.linspace (0,1,50)]
mixsin=  [x+y+z for x,y,z in zip(A,B,C)]
fft_wave = FFT.fft(mixsin)
plt.plot(mixsin)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-681bf5c8c53a> in <module>
#       7 c=d.SinSignal(freq=250,amp=4,offset=0)
#       8 d=d.SinSignal(freq=260,amp=5,offset=0)
# ----> 9 s=d.SinSignal(freq=280,amp=5,offset=0)
#      10 f=d.SinSignal(freq=300,amp=5,offset=0)
#      11 g=d.SinSignal(freq=330,amp=5,offset=0)
#
# AttributeError: 'Sinusoid' object has no attribute 'SinSignal'

# %%
import thinkdsp as d
from IPython.display import Audio
import thinkplot as t
from IPython.display import Audio
k=d.SinSignal(freq=520,amp=3,offset= 0)
l=d.SinSignal(freq=550,amp=3,offset=0)
m=d.SinSignal(freq=580,amp=4,offset=0)
n=d.SinSignal(freq=620,amp=5,offset=0)
o=d.SinSignal(freq=650,amp=5,offset=0)
p=d.SinSignal(freq=690,amp=5,offset=0)
q=d.SinSignal(freq=740,amp=5,offset=0)
r=d.SinSignal(freq=780,amp=5,offset=0)
s=d.SinSignal(freq=830,amp=5,offset=0)
t=d.SinSignal(freq=880,amp=5,offset=0)
u=d.SinSignal(freq=930,amp=5,offset=0)
v=d.SinSignal(freq=980,amp=5,offset=0)
w=d.SinSignal(freq=1040,amp=5,offset=0)
#r0=a+b+c+d
#r.plot()
k1=m.make_wave(duration=0.5,start=0,framerate=48000)
l1=n.make_wave(duration=0.5,start=0.5,framerate=48000)
m1=o.make_wave(duration=0.5,start=1,framerate=48000)
n1=p.make_wave(duration=0.5,start=1.5,framerate=48000)
o1=q.make_wave(duration=0.5,start=2,framerate=48000)
p1=r.make_wave(duration=0.5,start=2.5,framerate=48000)
q1=s.make_wave(duration=0.5,start=3,framerate=48000)
r1=t.make_wave(duration=0.5,start=3.5,framerate=48000)
s1=u.make_wave(duration=0.5,start=4,framerate=48000)
t1=v.make_wave(duration=0.5,start=4.5,framerate=48000)
u1=w.make_wave(duration=0.5,start=5,framerate=48000)
v1=x.make_wave(duration=0.5,start=5.5,framerate=48000)
w1=y.make_wave(duration=0.5,start=6,framerate=48000)
a= k1+l1+m1+n1+o1+p1+q1+r1+s1+t1+u1+v1+w1
b=Audio(data=a.ys,rate=a.framerate)
b
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import thinkdsp as t
import thinkplot as d
wave= read_wave("C:/user/asus/Downloads/100Hz_44100Hz_16bit_05sec):
wave.plot()
sag=wave.sagment(start=0,duretion=33)
aud=sag.make_audio()
spec=sag.make_specturm()
spec.plot(high=1000)
aud
